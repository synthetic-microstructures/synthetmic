# %% [markdown]
# # 3D basic usage of SynthetMic package: Voronoi diagrams
#
# <a href="https://colab.research.google.com/github/synthetic-microstructure/synthetmic/blob/main/examples/notebooks/voronoi/3d_basic_usage.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# In this example, we will show how to use `synthetmic` package to generate
# a 3D synthetic microstructure using Voronoi diagrams.
#
# We first install `synthetmic`.

# %%
# !pip install synthetmic

# %% [markdown]
# Next, we import the generator class and functions.

# %%
from synthetmic import VoronoiDiagramGenerator
from synthetmic.data import toy
from synthetmic.plot import plot_cells_as_pyvista_fig

# %% [markdown]
# We now create data for the diagram. Below, we create a unit cube with 100 grains.
#
# Note that you can always create your own custom data and not required to
# use the provided functions in `synthetmic`.

# %%
domain, _ = toy._create_unit_domain(space_dim=3)
seeds = toy.sample_random_seeds(domain=domain, n_grains=100, random_state=42)

domain, seeds

# %% [markdown]
# We then create an instance of `VoronoiDiagramGenerator` object, and call `fit` method on the created data.

# %%
diagram = VoronoiDiagramGenerator(
    n_iter=50,
    damp_param=1.0,
    verbose=True,
)
diagram.fit(
    seeds=seeds,
    domain=domain,
    periodic=None
)

# %% [markdown]
# Once the diagram is created, we can access many properties.
# For instance, the fitted volumes, vertices, centroids, mesh, etc.

# %%
diagram.get_fitted_volumes()

# %%
diagram.get_vertices()

# %%
diagram.get_centroids()

# %%
diagram.get_mesh()

# %% [markdown]
# With the help of plotting function, we can plot the generated diagram.

# %%
pl = plot_cells_as_pyvista_fig(generator=diagram, colorby=diagram.get_fitted_volumes(), notebook=True)
pl.show()

# %% [markdown]
# If you want periodicity in any coordinate (say all coordinates), we can specify
# this in the `fit` method as follows:

# %%
diagram.fit(
    seeds=seeds,
    domain=domain,
    periodic=[True, True, True]
)

# %% [markdown]
# and then plot the corresponding diagram as follows:

# %%
pl = plot_cells_as_pyvista_fig(generator=diagram, colorby=diagram.get_fitted_volumes(), notebook=True)
pl.show()
